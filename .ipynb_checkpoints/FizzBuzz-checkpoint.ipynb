# %%
FizzBuzz(maxNum) = sum(i for i in 1:maxNum-1 if i%3 == 0 || i%5 == 0)
# Out:
# FizzBuzz (generic function with 1 method)

# %%
print(FizzBuzz(10))
print("\n")
print(FizzBuzz(1000))
# Out:
# 23
# 233168
